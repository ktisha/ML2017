# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.colors import ListedColormap
from sklearn import model_selection

from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import tree
from sklearn import preprocessing

plt.rcParams['axes.facecolor'] = 'white'

# %%
pokemons = pd.read_csv("Pokemon2.csv")
pokemons.columns.unique()
# Out:
# Index(['Number', 'Name', 'Type_1', 'Type_2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp_Atk', 'Sp_Def', 'Speed', 'Generation', 'isLegendary',
#        'Color', 'hasGender', 'Pr_Male', 'Egg_Group_1', 'Egg_Group_2',
#        'hasMegaEvolution', 'Height_m', 'Weight_kg', 'Catch_Rate',
#        'Body_Style'],
#       dtype='object')

# %%
pokemons.drop('Number', 1)
# Out:
#            Name    Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0     Bulbasaur     Grass  Poison    318   45      49       49      65
# 1       Ivysaur     Grass  Poison    405   60      62       63      80
# 2      Venusaur     Grass  Poison    525   80      82       83     100
# 3    Charmander      Fire     NaN    309   39      52       43      60
# 4    Charmeleon      Fire     NaN    405   58      64       58      80
# 5     Charizard      Fire  Flying    534   78      84       78     109
# 6      Squirtle     Water     NaN    314   44      48       65      50
# 7     Wartortle     Water     NaN    405   59      63       80      65
# 8     Blastoise     Water     NaN    530   79      83      100      85
# 9      Caterpie       Bug     NaN    195   45      30       35      20
# 10      Metapod       Bug     NaN    205   50      20       55      25
# 11   Butterfree       Bug  Flying    395   60      45       50      90
# 12       Weedle       Bug  Poison    195   40      35       30      20
# 13       Kakuna       Bug  Poison    205   45      25       50      25
# 14     Beedrill       Bug  Poison    395   65      90       40      45
# 15       Pidgey    Normal  Flying    251   40      45       40      35
# 16    Pidgeotto    Normal  Flying    349   63      60       55      50
# 17      Pidgeot    Normal  Flying    479   83      80       75      70
# 18      Rattata    Normal     NaN    253   30      56       35      25
# 19     Raticate    Normal     NaN    413   55      81       60      50
# 20      Spearow    Normal  Flying    262   40      60       30      31
# 21       Fearow    Normal  Flying    442   65      90       65      61
# 22        Ekans    Poison     NaN    288   35      60       44      40
# 23        Arbok    Poison     NaN    438   60      85       69      65
# 24      Pikachu  Electric     NaN    320   35      55       40      50
# 25       Raichu  Electric     NaN    485   60      90       55      90
# 26    Sandshrew    Ground     NaN    300   50      75       85      20
# 27    Sandslash    Ground     NaN    450   75     100      110      45
# 28     Nidoran♀    Poison     NaN    275   55      47       52      40
# 29     Nidorina    Poison     NaN    365   70      62       67      55
# ..          ...       ...     ...    ...  ...     ...      ...     ...
# 691   Clauncher     Water     NaN    330   50      53       62      58
# 692   Clawitzer     Water     NaN    500   71      73       88     120
# 693  Helioptile  Electric  Normal    289   44      38       33      61
# 694   Heliolisk  Electric  Normal    481   62      55       52     109
# 695      Tyrunt      Rock  Dragon    362   58      89       77      45
# 696   Tyrantrum      Rock  Dragon    521   82     121      119      69
# 697      Amaura      Rock     Ice    362   77      59       50      67
# 698     Aurorus      Rock     Ice    521  123      77       72      99
# 699     Sylveon     Fairy     NaN    525   95      65       65     110
# 700    Hawlucha  Fighting  Flying    500   78      92       75      74
# 701     Dedenne  Electric   Fairy    431   67      58       57      81
# 702     Carbink      Rock   Fairy    500   50      50      150      50
# 703       Goomy    Dragon     NaN    300   45      50       35      55
# 704     Sliggoo    Dragon     NaN    452   68      75       53      83
# 705      Goodra    Dragon     NaN    600   90     100       70     110
# 706      Klefki     Steel   Fairy    470   57      80       91      80
# 707    Phantump     Ghost   Grass    309   43      70       48      50
# 708   Trevenant     Ghost   Grass    474   85     110       76      65
# 709   Pumpkaboo     Ghost   Grass    335   49      66       70      44
# 710   Gourgeist     Ghost   Grass    494   65      90      122      58
# 711    Bergmite       Ice     NaN    304   55      69       85      32
# 712     Avalugg       Ice     NaN    514   95     117      184      44
# 713      Noibat    Flying  Dragon    245   40      30       35      45
# 714     Noivern    Flying  Dragon    535   85      70       80      97
# 715     Xerneas     Fairy     NaN    680  126     131       95     131
# 716     Yveltal      Dark  Flying    680  126     131       95     131
# 717     Zygarde    Dragon  Ground    600  108     100      121      81
# 718     Diancie      Rock   Fairy    600   50     100      150     100
# 719       Hoopa   Psychic   Ghost    600   80     110       60     150
# 720   Volcanion      Fire   Water    600   80     110      120     130
#
#      Sp_Def  Speed        ...          Color hasGender Pr_Male   Egg_Group_1  \
# 0        65     45        ...          Green      True   0.875       Monster
# 1        80     60        ...          Green      True   0.875       Monster
# 2       100     80        ...          Green      True   0.875       Monster
# 3        50     65        ...            Red      True   0.875       Monster
# 4        65     80        ...            Red      True   0.875       Monster
# 5        85    100        ...            Red      True   0.875       Monster
# 6        64     43        ...           Blue      True   0.875       Monster
# 7        80     58        ...           Blue      True   0.875       Monster
# 8       105     78        ...           Blue      True   0.875       Monster
# 9        20     45        ...          Green      True   0.500           Bug
# 10       25     30        ...          Green      True   0.500           Bug
# 11       80     70        ...          White      True   0.500           Bug
# 12       20     50        ...          Brown      True   0.500           Bug
# 13       25     35        ...         Yellow      True   0.500           Bug
# 14       80     75        ...         Yellow      True   0.500           Bug
# 15       35     56        ...          Brown      True   0.500        Flying
# 16       50     71        ...          Brown      True   0.500        Flying
# 17       70    101        ...          Brown      True   0.500        Flying
# 18       35     72        ...         Purple      True   0.500         Field
# 19       70     97        ...          Brown      True   0.500         Field
# 20       31     70        ...          Brown      True   0.500        Flying
# 21       61    100        ...          Brown      True   0.500        Flying
# 22       54     55        ...         Purple      True   0.500         Field
# 23       79     80        ...         Purple      True   0.500         Field
# 24       50     90        ...         Yellow      True   0.500         Field
# 25       80    110        ...         Yellow      True   0.500         Field
# 26       30     40        ...         Yellow      True   0.500         Field
# 27       55     65        ...         Yellow      True   0.500         Field
# 28       40     41        ...           Blue      True   0.000       Monster
# 29       55     56        ...           Blue      True   0.000  Undiscovered
# ..      ...    ...        ...            ...       ...     ...           ...
# 691      63     44        ...           Blue      True   0.500       Water_1
# 692      89     59        ...           Blue      True   0.500       Water_1
# 693      43     70        ...         Yellow      True   0.500       Monster
# 694      94    109        ...         Yellow      True   0.500       Monster
# 695      45     48        ...          Brown      True   0.875       Monster
# 696      59     71        ...            Red      True   0.875       Monster
# 697      63     46        ...           Blue      True   0.875       Monster
# 698      92     58        ...           Blue      True   0.875       Monster
# 699     130     60        ...           Pink      True   0.875         Field
# 700      63    118        ...          Green      True   0.500    Human-Like
# 701      67    101        ...         Yellow      True   0.500         Field
# 702     150     50        ...           Grey     False     NaN         Fairy
# 703      75     40        ...         Purple      True   0.500        Dragon
# 704     113     60        ...         Purple      True   0.500        Dragon
# 705     150     80        ...         Purple      True   0.500        Dragon
# 706      87     75        ...           Grey      True   0.500       Mineral
# 707      60     38        ...          Brown      True   0.500         Grass
# 708      82     56        ...          Brown      True   0.500         Grass
# 709      55     51        ...          Brown      True   0.500     Amorphous
# 710      75     84        ...          Brown      True   0.500     Amorphous
# 711      35     28        ...           Blue      True   0.500       Monster
# 712      46     28        ...           Blue      True   0.500       Monster
# 713      40     55        ...         Purple      True   0.500        Flying
# 714      80    123        ...         Purple      True   0.500        Flying
# 715      98     99        ...           Blue     False     NaN  Undiscovered
# 716      98     99        ...            Red     False     NaN  Undiscovered
# 717      95     95        ...          Green     False     NaN  Undiscovered
# 718     150     50        ...           Pink     False     NaN  Undiscovered
# 719     130     70        ...         Purple     False     NaN  Undiscovered
# 720      90     70        ...          Brown     False     NaN  Undiscovered
#
#      Egg_Group_2 hasMegaEvolution Height_m Weight_kg  Catch_Rate  \
# 0          Grass            False     0.71       6.9          45
# 1          Grass            False     0.99      13.0          45
# 2          Grass             True     2.01     100.0          45
# 3         Dragon            False     0.61       8.5          45
# 4         Dragon            False     1.09      19.0          45
# 5         Dragon             True     1.70      90.5          45
# 6        Water_1            False     0.51       9.0          45
# 7        Water_1            False     0.99      22.5          45
# 8        Water_1             True     1.60      85.5          45
# 9            NaN            False     0.30       2.9         255
# 10           NaN            False     0.71       9.9         120
# 11           NaN            False     1.09      32.0          45
# 12           NaN            False     0.30       3.2         255
# 13           NaN            False     0.61      10.0         120
# 14           NaN             True     0.99      29.5          45
# 15           NaN            False     0.30       1.8         255
# 16           NaN            False     1.09      30.0         120
# 17           NaN             True     1.50      39.5          45
# 18           NaN            False     0.30       3.5         255
# 19           NaN            False     0.71      18.5         127
# 20           NaN            False     0.30       2.0         255
# 21           NaN            False     1.19      38.0          90
# 22        Dragon            False     2.01       6.9         255
# 23        Dragon            False     3.51      65.0          90
# 24         Fairy            False     0.41       6.0         190
# 25         Fairy            False     0.79      30.0          75
# 26           NaN            False     0.61      12.0         255
# 27           NaN            False     0.99      29.5          90
# 28         Field            False     0.41       7.0         235
# 29           NaN            False     0.79      20.0         120
# ..           ...              ...      ...       ...         ...
# 691      Water_3            False     0.51       8.3         225
# 692      Water_3            False     1.30      35.3          55
# 693       Dragon            False     0.51       6.0         190
# 694       Dragon            False     0.99      21.0          75
# 695       Dragon            False     0.79      26.0          45
# 696       Dragon            False     2.49     270.0          45
# 697          NaN            False     1.30      25.2          45
# 698          NaN            False     2.69     225.0          45
# 699          NaN            False     0.99      23.5          45
# 700          NaN            False     0.79      21.5         100
# 701        Fairy            False     0.20       2.2         180
# 702      Mineral            False     0.30       5.7          60
# 703          NaN            False     0.30       2.8          45
# 704          NaN            False     0.79      17.5          45
# 705          NaN            False     2.01     150.5          45
# 706          NaN            False     0.20       3.0          75
# 707    Amorphous            False     0.41       7.0         120
# 708    Amorphous            False     1.50      71.0          60
# 709          NaN            False     0.41       5.0         120
# 710          NaN            False     1.70      39.0          60
# 711          NaN            False     0.99      99.5         190
# 712          NaN            False     2.01     505.0          55
# 713          NaN            False     0.51       8.0         190
# 714          NaN            False     1.50      85.0          45
# 715          NaN            False     3.00     215.0          45
# 716          NaN            False     5.79     203.0          45
# 717          NaN            False     5.00     305.0           3
# 718          NaN             True     0.71       8.8           3
# 719          NaN            False     0.51       9.0           3
# 720          NaN            False     1.70     195.0           3
#
#            Body_Style
# 0           quadruped
# 1           quadruped
# 2           quadruped
# 3      bipedal_tailed
# 4      bipedal_tailed
# 5      bipedal_tailed
# 6      bipedal_tailed
# 7      bipedal_tailed
# 8      bipedal_tailed
# 9           insectoid
# 10    serpentine_body
# 11         four_wings
# 12    serpentine_body
# 13    serpentine_body
# 14         four_wings
# 15          two_wings
# 16          two_wings
# 17          two_wings
# 18          quadruped
# 19          quadruped
# 20          two_wings
# 21          two_wings
# 22    serpentine_body
# 23    serpentine_body
# 24          quadruped
# 25     bipedal_tailed
# 26     bipedal_tailed
# 27     bipedal_tailed
# 28          quadruped
# 29          quadruped
# ..                ...
# 691         insectoid
# 692   serpentine_body
# 693    bipedal_tailed
# 694    bipedal_tailed
# 695    bipedal_tailed
# 696    bipedal_tailed
# 697         quadruped
# 698         quadruped
# 699         quadruped
# 700  bipedal_tailless
# 701    bipedal_tailed
# 702         head_only
# 703   serpentine_body
# 704   serpentine_body
# 705    bipedal_tailed
# 706         head_only
# 707         head_arms
# 708     several_limbs
# 709         head_only
# 710         head_base
# 711         quadruped
# 712         quadruped
# 713         two_wings
# 714         two_wings
# 715         quadruped
# 716         two_wings
# 717   serpentine_body
# 718         head_arms
# 719         head_only
# 720         quadruped
#
# [721 rows x 22 columns]

# %%
pokemons.head()
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    Sp_Def       ...        Color  hasGender Pr_Male Egg_Group_1 Egg_Group_2  \
# 0      65       ...        Green       True   0.875     Monster       Grass
# 1      80       ...        Green       True   0.875     Monster       Grass
# 2     100       ...        Green       True   0.875     Monster       Grass
# 3      50       ...          Red       True   0.875     Monster      Dragon
# 4      65       ...          Red       True   0.875     Monster      Dragon
#
#    hasMegaEvolution Height_m Weight_kg Catch_Rate      Body_Style
# 0             False     0.71       6.9         45       quadruped
# 1             False     0.99      13.0         45       quadruped
# 2              True     2.01     100.0         45       quadruped
# 3             False     0.61       8.5         45  bipedal_tailed
# 4             False     1.09      19.0         45  bipedal_tailed
#
# [5 rows x 23 columns]

# %%
categorical = ['Type_1', 'Egg_Group_1', 'Body_Style', 'Color']
X = pokemons.ix[:, pokemons.columns != 'isLegendary']
X = X.drop("Name", 1)
X = X.drop("Type_2", 1)
X = X.drop("Egg_Group_2", 1)
X = X.drop("Pr_Male", 1)
enc = preprocessing.LabelEncoder()

for c in categorical:
    X[[c]] = enc.fit_transform(X[[c]])


y = pokemons[['isLegendary']]
# X = pd.get_dummies(X)


clf = tree.DecisionTreeClassifier()
clf.fit(X, y)


import pydotplus 
dot_data = tree.export_graphviz(clf, out_file='tree.dot', 
                         feature_names=X.columns,  
                         class_names=['Legendary', 'Not Legendary'],  
                         filled=True, rounded=True,  
                         special_characters=False, impurity=False, proportion=True)
# Out:
# /home/ktisha/.virtualenvs/ML17/lib/python3.5/site-packages/sklearn/preprocessing/label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
graph = pydotplus.graph_from_dot_file("tree.dot")  
graph.write_pdf("tree.pdf")
# Out:
# True
